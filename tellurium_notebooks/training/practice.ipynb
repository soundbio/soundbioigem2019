# %%
model r()
# This model describes simple central dogma
    J0: -> M ; a_m        #production of mRNA
    J1: M -> ; d_m*M      #degradation of mRNA 
    J2: M -> P ; a_p*M    #production of protein
    J3: P -> ; d_p*P      #degradation of protein
    
    # Parameters
    a_m = 10; d_m = 1     #prod and deg of mRNA
    a_p = 500; d_p = 0.05 #prod and deg of protein
    
    # Initial values (every species needs I.V.)
    M = 0
    P = 0
end
# Out:
# Success: Model can be accessed via variable r

# %%
import numpy as np
import matplotlib.pyplot as plt
import tellurium as te 
import time

#clears out any previous simulation results if it exists
r.reset() 

#the simulation is run, and is saved in "r.model", 
#but results are also stored in "result" by the line below
result = r.simulate(0,200,1000) #(start, end, timepoints)

# Find the steady-state value of Protein
P_ss = result[-1,2]

r.plot() # quick plot of model results
#You can do something like the following to alter the quick plot
#r.plot(ylim=[0,300])
# Out:
# <div id="76f036b0-3d96-4467-934c-dcaa2b4034e0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("76f036b0-3d96-4467-934c-dcaa2b4034e0", [{"type": "scatter", "x": [0.0, 0.2002002002002002, 0.4004004004004004, 0.6006006006006006, 0.8008008008008008, 1.001001001001001, 1.2012012012012012, 1.4014014014014016, 1.6016016016016017, 1.8018018018018018, 2.002002002002002, 2.2022022022022023, 2.4024024024024024, 2.6026026026026026, 2.802802802802803, 3.0030030030030033, 3.2032032032032034, 3.4034034034034035, 3.6036036036036037, 3.8038038038038042, 4.004004004004004, 4.2042042042042045, 4.404404404404405, 4.604604604604605, 4.804804804804805, 5.005005005005005, 5.205205205205205, 5.405405405405406, 5.605605605605606, 5.805805805805806, 6.0060060060060065, 6.206206206206207, 6.406406406406407, 6.606606606606607, 6.806806806806807, 7.007007007007007, 7.207207207207207, 7.407407407407407, 7.6076076076076085, 7.807807807807809, 8.008008008008009, 8.208208208208209, 8.408408408408409, 8.608608608608609, 8.80880880880881, 9.00900900900901, 9.20920920920921, 9.40940940940941, 9.60960960960961, 9.80980980980981, 10.01001001001001, 10.21021021021021, 10.41041041041041, 10.61061061061061, 10.810810810810812, 11.011011011011012, 11.211211211211213, 11.411411411411413, 11.611611611611613, 11.811811811811813, 12.012012012012013, 12.212212212212213, 12.412412412412413, 12.612612612612613, 12.812812812812814, 13.013013013013014, 13.213213213213214, 13.413413413413414, 13.613613613613614, 13.813813813813814, 14.014014014014014, 14.214214214214214, 14.414414414414415, 14.614614614614615, 14.814814814814815, 15.015015015015017, 15.215215215215217, 15.415415415415417, 15.615615615615617, 15.815815815815817, 16.016016016016017, 16.216216216216218, 16.416416416416418, 16.616616616616618, 16.816816816816818, 17.017017017017018, 17.217217217217218, 17.41741741741742, 17.61761761761762, 17.81781781781782, 18.01801801801802, 18.21821821821822, 18.41841841841842, 18.61861861861862, 18.81881881881882, 19.01901901901902, 19.21921921921922, 19.41941941941942, 19.61961961961962, 19.81981981981982, 20.02002002002002, 20.22022022022022, 20.42042042042042, 20.62062062062062, 20.82082082082082, 21.02102102102102, 21.22122122122122, 21.421421421421424, 21.621621621621625, 21.821821821821825, 22.022022022022025, 22.222222222222225, 22.422422422422425, 22.622622622622625, 22.822822822822825, 23.023023023023026, 23.223223223223226, 23.423423423423426, 23.623623623623626, 23.823823823823826, 24.024024024024026, 24.224224224224226, 24.424424424424426, 24.624624624624627, 24.824824824824827, 25.025025025025027, 25.225225225225227, 25.425425425425427, 25.625625625625627, 25.825825825825827, 26.026026026026027, 26.226226226226228, 26.426426426426428, 26.626626626626628, 26.826826826826828, 27.027027027027028, 27.227227227227228, 27.42742742742743, 27.62762762762763, 27.82782782782783, 28.02802802802803, 28.22822822822823, 28.42842842842843, 28.62862862862863, 28.82882882882883, 29.02902902902903, 29.22922922922923, 29.42942942942943, 29.62962962962963, 29.82982982982983, 30.030030030030034, 30.230230230230234, 30.430430430430434, 30.630630630630634, 30.830830830830834, 31.031031031031034, 31.231231231231234, 31.431431431431434, 31.631631631631635, 31.831831831831835, 32.032032032032035, 32.232232232232235, 32.432432432432435, 32.632632632632635, 32.832832832832835, 33.033033033033036, 33.233233233233236, 33.433433433433436, 33.633633633633636, 33.833833833833836, 34.034034034034036, 34.234234234234236, 34.434434434434436, 34.63463463463464, 34.83483483483484, 35.03503503503504, 35.23523523523524, 35.43543543543544, 35.63563563563564, 35.83583583583584, 36.03603603603604, 36.23623623623624, 36.43643643643644, 36.63663663663664, 36.83683683683684, 37.03703703703704, 37.23723723723724, 37.437437437 ...

# %%
### Plotting "result" using matplotlib (more customizable)
#plot mRMA
plt.figure(1)
plt.subplot(211)
plt.plot(result[:,0], result[:,1], 'r', label = "mRNA")
plt.ylabel('Copies', fontsize='12') 
plt.xlabel('Time (hr)', fontsize='12')
plt.legend(loc=4)
#plot protein
plt.subplot(212)
plt.plot(result[:,0], result[:,2], 'b', label = "Protein")
plt.plot([0,200], [P_ss,P_ss], 'k--', label = "Steady-State")
plt.ylim([0,120000])
plt.ylabel('Copies', fontsize='12') 
plt.xlabel('Time (hr)', fontsize='12')
plt.legend(loc=4)
plt.tight_layout()

# %%
#%% Doing a parametric sweep using a for loop

# Investigate the input output relationship between 
# steady state Protein levels (P_ss)
# and mRNA production rate (a_m)
# or mRNA decay rate (d_m)

a_m = np.linspace(1,50,50)
#d_m = np.linspace(0.01, 10,10)     
d_m = np.array([0.0001,0.001,0.01,0.1,1,10,100])
P_ss = np.zeros(len(d_m))
T_r = np.zeros(len(d_m))
count = 0
for i in d_m:
    r = te.loada("""
        J0: -> M ; a_m
        J1: M -> ; d_m*M
        J2: M -> P ; a_p*M
        J3: P -> ; d_p*P
        
        # Parameters
        a_m = 10
        a_p = 500; d_p = 0.05
        
        # Initial values
        M = 0
        P = 0
        """
        # Iterating parameters
        "d_m = " + str(i) + ";"
    )
    result = r.simulate(0,200,1000)
    
    # Find the steady-state value
    P_ss[count] = result[-1,2]
    
#    print 'd_m =',d_m[count] #verbose print of current d_m value
    
    plt.figure(3)
    plt.semilogy(result[:,0],result[:,2],label=d_m[count])
    plt.legend()
    plt.xlabel("time")
    plt.ylabel("Protein")
    
    plt.figure(4)
    plt.plot(result[:,0],result[:,1],label=d_m[count])
    plt.legend()
    plt.xlabel("time")
    plt.ylabel("mRNA")
    
    time.sleep(.25)
   
### or you can print them one at a time.
#    if d_m[count] < 1:
#        r.plot(ylim=[0,10000000])
#    if d_m[count] >= 1:
#        r.plot(ylim=[0,100000])
#    time.sleep(.25)
   
    count += 1

# %%
#compare steady-state levels
plt.figure(5)
plt.hist(P_ss)
plt.xlabel("Protein value at Steady-state")

# %% [markdown]
# # Metabolic networks
#
# * Assume there is no external degradation unless specified.
# * Assume all production rates are at unity.
# * Assume boundary species are set to 10 counts.
# * Assume initial values of floating species are at 0.

# %% [markdown]
# # Make a model of the first linear pathway
# <img src="https://i.imgur.com/qUU0cea.jpg" alt="drawing" width="1000"/>

# %%
model one
    J0: $X0 -> S1 ; v_1 * X0    #you can put a $ sign before a species to set it to a boundary species (concentration doesn't change)
    J1: #### FILL IN THESE
    J2: 
    J3: 
    J4: # You will have tomake X5 a boundary species as well.
    
    # Parameters
    v_1 = 1 
    v_2 = 3
    v_3 = 5
    v_4 = 2
    v_5 = 1
    
    # Initial values
    X0 = 10
    X5 = 10
    S1 = 0
    S2 = 0
    S3 = 0
    S4 = 0
end

# %%
one.reset()
result = one.simulate(0,20,200)
one.plot()
one.getSteadyStateValues()

# %% [markdown]
# # Make a model of the second pathway (w/ feedback)
# <img src="https://i.imgur.com/LTvgqC2.jpg" alt="drawing" width="800"/>

# %%
model two
    J0: $X0 -> S1 ; v_1 * X0 * (K/(K+S3))
    J1:  #### FILL IN THESE
    J2:  
    J3: 
    # Parameters
    K = 10
    v_1 = 1
    v_2 = 2
    v_3 = 3
    v_4 = 4
    # Initial values
    X0 = 5
    X1 = 10
    S1 = 0
    S2 = 0
    S3 = 0
end
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-499aea068822> in <module>()
# ----> 1 get_ipython().run_cell_magic('crn', '', 'model two\n    J0: $X0 -> S1 ; v_1 * X0 * (K/(K+S3))\n    J1: \n    J2:  \n    J3: \n    # Parameters\n    K = 10\n    v_1 = 1\n    v_2 = 2\n    v_3 = 3\n    v_4 = 4\n    # Initial values\n    X0 = 5\n    X1 = 10\n    S1 = 0\n    S2 = 0\n    S3 = 0\nend')
#
# ~\AppData\Roaming\Tellurium\telocal\python-3.6.2\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-160> in crn(self, line, cell)
#
# ~\AppData\Roaming\Tellurium\telocal\python-3.6.2\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Roaming\Tellurium\telocal\python-3.6.2\lib\site-packages\temagics\magics.py in crn(self, line, cell)
#      40
#      41         # convert cell content (Antimony) to raw SBML
# ---> 42         module,sbml_str = antimonyConverter().antimonyToSBML(cell)
#      43
#      44         # override name?
#
# ~\AppData\Roaming\Tellurium\telocal\python-3.6.2\lib\site-packages\tellurium\teconverters\convert_antimony.py in antimonyToSBML(self, sb_str, SBO)
#      94         if self.checkAntimonyReturnCode(code):
#      95             errors = sb.getLastError()
# ---> 96             raise RuntimeError('Errors encountered when trying to load model into Antimony:\n{}'.format(errors))
#      97
#      98         module = sb.getMainModuleName()
#
# RuntimeError: Errors encountered when trying to load model into Antimony:
# Error in model string, line 3:  syntax error, unexpected '\n', expecting '-' or '+' or => or '<'

# %%
two.reset()
result = two.simulate(0,30,200)
two.plot()

# %% [markdown]
# # Make a model of this third complex pathway.
# <img src="https://i.imgur.com/wizPbcl.jpg" alt="drawing" width="600"/>

# %%
model three
    J0: -> S1 ; v1
    J1:  #### FILL IN THESE
    J2: 
    J3: 
    J4: 
    J5: 
    
    # Parameters
    v1 = 1
    v2 = 1
    v3 = 1
    v4 = 1
    v5 = 1
    v6 = 1
    
    # Initial values
    S1 = 0
    S2 = 0
    S3 = 0
end

# %%
three.reset()
result = three.simulate(0,30,200)
three.plot()
